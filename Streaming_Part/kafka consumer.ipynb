# %%
from kafka import KafkaConsumer
import json
import csv
import os

# Create a Kafka consumer instance
consumer = KafkaConsumer(
    'skippy',  # The Kafka topic you're consuming from
    bootstrap_servers='localhost:9092',  # Address of your Kafka broker
    group_id='SmsGroup',  # Consumer group ID
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))  # Deserialize the message from JSON
)

# CSV file path
csv_file_path = 'saved_from_stream.csv'

# Check if the CSV file already exists
file_exists = os.path.exists(csv_file_path)

# Define the expected fieldnames based on the incoming data
fieldnames = [
    'Invoice ID', 'Line', 'Customer ID', 'Product ID', 'Size', 'Color', 'Unit Price', 'Quantity',
    'Date', 'Discount', 'Line Total', 'Store ID', 'Employee ID', 'Currency', 'Currency Symbol',
    'SKU', 'Transaction Type', 'Payment Method', 'Invoice Total'
]

# Open the CSV file in append mode
with open(csv_file_path, mode='a', newline='', encoding='utf-8') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    # Write the header only if the file doesn't already exist
    if not file_exists:
        writer.writeheader()

    # Counter to stop after a certain number of records
    record_count = 0
    max_records = 15

    # Consume messages from Kafka
    for message in consumer:
        if record_count >= max_records:
            print("✅ Reached 15 records. Stopping the consumer.")
            break

        data = message.value

        # Check for any unexpected fields in the data
        extra_fields = set(data.keys()) - set(fieldnames)
        if extra_fields:
            print(f"⚠️ Extra fields found and ignored: {extra_fields}")

        # Keep only the fields defined in fieldnames
        filtered_data = {key: data.get(key, '') for key in fieldnames}

        # Write the filtered data to the CSV
        writer.writerow(filtered_data)
        csv_file.flush()
        print(f"💾 Saved: {filtered_data}")

        record_count += 1
# Out:
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-CN-006-03123323', 'Line': '1', 'Customer ID': '395766', 'Product ID': '15782', 'Size': 'N', 'Color': 'Black', 'Unit Price': '269.5', 'Quantity': '1', 'Date': '2025-04-15', 'Discount': '0', 'Line Total': '269.5', 'Store ID': '6', 'Employee ID': '71', 'Currency': 'CNY', 'Currency Symbol': '', 'SKU': 'CHAC15782--', 'Transaction Type': 'Sale', 'Payment Method': 'Credit Card', 'Invoice Total': '1233.53'}
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-CN-006-03123323', 'Line': '2', 'Customer ID': '395766', 'Product ID': '16474', 'Size': '38', 'Color': 'Black', 'Unit Price': '809', 'Quantity': '1', 'Date': '2025-04-15', 'Discount': '0', 'Line Total': '809', 'Store ID': '6', 'Employee ID': '71', 'Currency': 'CNY', 'Currency Symbol': '', 'SKU': 'MAPA16474-38-', 'Transaction Type': 'Sale', 'Payment Method': 'Credit Card', 'Invoice Total': '1233.53'}
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-CN-006-03123323', 'Line': '3', 'Customer ID': '395766', 'Product ID': '16186', 'Size': 'XXL', 'Color': 'BLUE', 'Unit Price': '238.5', 'Quantity': '1', 'Date': '2025-04-15', 'Discount': '0.35', 'Line Total': '155.03', 'Store ID': '6', 'Employee ID': '71', 'Currency': 'CNY', 'Currency Symbol': '', 'SKU': 'MAT-16186-XXL-BLUE', 'Transaction Type': 'Sale', 'Payment Method': 'Credit Card', 'Invoice Total': '1233.53'}
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-CN-006-03123350', 'Line': '1', 'Customer ID': '371787', 'Product ID': '16460', 'Size': 'M', 'Color': 'BEIGE', 'Unit Price': '451', 'Quantity': '1', 'Date': '2025-04-15', 'Discount': '0', 'Line Total': '451', 'Store ID': '6', 'Employee ID': '68', 'Currency': 'CNY', 'Currency Symbol': '', 'SKU': 'FESW16460-M-BEIGE', 'Transaction Type': 'Sale', 'Payment Method': 'Credit Card', 'Invoice Total': '451'}
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-CN-006-03123451', 'Line': '1', 'Customer ID': '648432', 'Product ID': '15929', 'Size': 'M', 'Color': 'Black', 'Unit Price': '1105', 'Quantity': '1', 'Date': '2025-04-15', 'Discount': '0', 'Line Total': '1105', 'Store ID': '6', 'Employee ID': '66', 'Currency': 'CNY', 'Currency Symbol': '', 'SKU': 'MASU15929-M-', 'Transaction Type': 'Sale', 'Payment Method': 'Credit Card', 'Invoice Total': '1326.33'}
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-CN-006-03123451', 'Line': '2', 'Customer ID': '648432', 'Product ID': '17008', 'Size': 'L', 'Color': 'Black', 'Unit Price': '340.5', 'Quantity': '1', 'Date': '2025-04-15', 'Discount': '0.35', 'Line Total': '221.33', 'Store ID': '6', 'Employee ID': '66', 'Currency': 'CNY', 'Currency Symbol': '', 'SKU': 'FESH17008-L-', 'Transaction Type': 'Sale', 'Payment Method': 'Credit Card', 'Invoice Total': '1326.33'}
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-CN-008-01645265', 'Line': '1', 'Customer ID': '481583', 'Product ID': '17435', 'Size': 'L', 'Color': 'Black', 'Unit Price': '199', 'Quantity': '1', 'Date': '2025-04-15', 'Discount': '0.35', 'Line Total': '129.35', 'Store ID': '8', 'Employee ID': '98', 'Currency': 'CNY', 'Currency Symbol': '', 'SKU': 'MASH17435-L-', 'Transaction Type': 'Sale', 'Payment Method': 'Credit Card', 'Invoice Total': '129.35'}
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-CN-009-05130121', 'Line': '1', 'Customer ID': '573924', 'Product ID': '15986', 'Size': 'P', 'Color': 'YELLOW', 'Unit Price': '314', 'Quantity': '1', 'Date': '2025-04-15', 'Discount': '0.35', 'Line Total': '204.1', 'Store ID': '9', 'Employee ID': '105', 'Currency': 'CNY', 'Currency Symbol': '', 'SKU': 'CHGI15986-P-YELLOW', 'Transaction Type': 'Sale', 'Payment Method': 'Credit Card', 'Invoice Total': '204.1'}
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-CN-009-05130145', 'Line': '1', 'Customer ID': '606514', 'Product ID': '17591', 'Size': 'XXL', 'Color': 'Black', 'Unit Price': '278.5', 'Quantity': '1', 'Date': '2025-04-15', 'Discount': '0.35', 'Line Total': '181.03', 'Store ID': '9', 'Employee ID': '103', 'Currency': 'CNY', 'Currency Symbol': '', 'SKU': 'MASH17591-XXL-', 'Transaction Type': 'Sale', 'Payment Method': 'Credit Card', 'Invoice Total': '181.03'}
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-DE-011-03367510', 'Line': '1', 'Customer ID': '698763', 'Product ID': '16020', 'Size': 'L', 'Color': 'Black', 'Unit Price': '22', 'Quantity': '1', 'Date': '2025-04-15', 'Discount': '0.35', 'Line Total': '14.3', 'Store ID': '11', 'Employee ID': '128', 'Currency': 'EUR', 'Currency Symbol': '', 'SKU': 'FESH16020-L-', 'Transaction Type': 'Sale', 'Payment Method': 'Credit Card', 'Invoice Total': '14.3'}
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-ES-026-04819184', 'Line': '1', 'Customer ID': '1295880', 'Product ID': '15927', 'Size': 'M', 'Color': 'Black', 'Unit Price': '27', 'Quantity': '2', 'Date': '2025-04-15', 'Discount': '0.35', 'Line Total': '35.1', 'Store ID': '26', 'Employee ID': '302', 'Currency': 'EUR', 'Currency Symbol': '', 'SKU': 'MASH15927-M-', 'Transaction Type': 'Sale', 'Payment Method': 'Cash', 'Invoice Total': '35.1'}
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-ES-030-04414994', 'Line': '1', 'Customer ID': '1366107', 'Product ID': '17245', 'Size': 'S', 'Color': 'Black', 'Unit Price': '29.5', 'Quantity': '1', 'Date': '2025-04-15', 'Discount': '0', 'Line Total': '29.5', 'Store ID': '30', 'Employee ID': '346', 'Currency': 'EUR', 'Currency Symbol': '', 'SKU': 'FESK17245-S-', 'Transaction Type': 'Sale', 'Payment Method': 'Credit Card', 'Invoice Total': '56.48'}
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-ES-030-04414994', 'Line': '2', 'Customer ID': '1366107', 'Product ID': '15120', 'Size': 'M', 'Color': 'YELLOW', 'Unit Price': '41.5', 'Quantity': '1', 'Date': '2025-04-15', 'Discount': '0.35', 'Line Total': '26.98', 'Store ID': '30', 'Employee ID': '346', 'Currency': 'EUR', 'Currency Symbol': '', 'SKU': 'MAT-15120-M-YELLOW', 'Transaction Type': 'Sale', 'Payment Method': 'Credit Card', 'Invoice Total': '56.48'}
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-FR-024-03707159', 'Line': '1', 'Customer ID': '1210912', 'Product ID': '15936', 'Size': 'P', 'Color': 'Black', 'Unit Price': '44.5', 'Quantity': '1', 'Date': '2025-04-15', 'Discount': '0', 'Line Total': '44.5', 'Store ID': '24', 'Employee ID': '275', 'Currency': 'EUR', 'Currency Symbol': '', 'SKU': 'CHSW15936-P-', 'Transaction Type': 'Sale', 'Payment Method': 'Credit Card', 'Invoice Total': '44.5'}
# ⚠️ Extra fields found and ignored: {'', 'Time'}
# 💾 Saved: {'Invoice ID': 'INV-FR-025-03001163', 'Line': '1', 'Customer ID': '1244260', 'Product ID': '17553', 'Size': 'M', 'Color': 'WHITE', 'Unit Price': '42.5', 'Quantity': '1', 'Date': '2025-04-15', 'Discount': '0.35', 'Line Total': '27.62', 'Store ID': '25', 'Employee ID': '287', 'Currency': 'EUR', 'Currency Symbol': '', 'SKU': 'FEDR17553-M-WHITE', 'Transaction Type': 'Sale', 'Payment Method': 'Credit Card', 'Invoice Total': '78.62'}
# ✅ Reached 15 records. Stopping the consumer.
